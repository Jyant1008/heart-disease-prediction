# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# #### age-age of patient
# #### sex-male of female
# #### chest pain type (4 values)
# #### resting blood pressure of patient
# #### serum cholestoral in mg/dl
# #### fasting blood sugar > 120 mg/dl
# #### resting electrocardiographic results (values 0,1,2)
# #### maximum heart rate achieved
# #### exercise induced angina
# #### oldpeak = ST depression induced by exercise relative to rest
# #### the slope of the peak exercise ST segment
# #### number of major vessels (0-3) colored by flourosopy
# #### thal: 0 = normal; 1 = fixed defect; 2 = reversable defect

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ## no null values in the data set

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=df.select_dtypes(exclude='object').corr(), cmap="rocket",annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Their is not any strong correlation between two feature in the given dataset

# %%
sns.histplot(df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### age is normally distributed

# %%
sns.histplot(df["trestbps"])
# Out:
# <Axes: xlabel='trestbps', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
target_dist=df["target"].value_counts()
plt.pie(target_dist,labels=target_dist.index,autopct='%1.1f%%')
plt.title("target")
# Out:
# Text(0.5, 1.0, 'target')

# %% [markdown]
# # In the given dataset half people has disease and half doesn't

# %%
plt.figure(figsize=(6,3))
sns.countplot(data=df,x='sex',hue='target')
plt.title("Distribution of target with Sex\n 0-male,1-female")
# Out:
# Text(0.5, 1.0, 'Distribution of target with Sex\n 0-male,1-female')

# %%
###

# %% [markdown]
# ### Man has more heart disease as compare to women

# %% [markdown]
# # Train Test split and scaling

# %%
Y=df["target"]

# %%
X=df.drop('target',axis=1)

# %%
X
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# 2         0   0     3
# 3         2   1     3
# 4         1   3     2
# ...     ...  ..   ...
# 1020      2   0     2
# 1021      1   1     3
# 1022      1   1     2
# 1023      2   0     2
# 1024      1   1     3
#
# [1025 rows x 13 columns]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=.25,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

stand_scale= StandardScaler()

# %%
 X_train=stand_scale.fit_transform(X_train)
 X_test=stand_scale.transform(X_test)

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Logistic Regression

# %%
m1="Logistic Regression"
lr_model = LogisticRegression(solver="liblinear",random_state=2 )
lr_model.fit(X_train, Y_train)
X_train_prediction = lr_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)

X_test_prediction = lr_model.predict(X_test)
test_data_accuracy_lr = accuracy_score(X_test_prediction, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_lr*100)

LR_conf_matrix = confusion_matrix(Y_test, X_test_prediction)
print("Confussion matrix")
print(LR_conf_matrix)
# Out:
# Accuracy on Training data:  84.89583333333334
# Accuracy on Test data:  82.87937743190662
# Confussion matrix
# [[102  36]
#  [  8 111]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score,log_loss, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score,classification_report
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
m2="Naive Bayes"

nb = GaussianNB()
# training the model with training data
nb.fit(X_train,Y_train)
# Accuracy on training data
X_train_prediction = nb.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)
# Accuracy on test data
X_test_prediction = nb.predict(X_test)
test_data_accuracy_nb = accuracy_score(X_test_prediction, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_nb*100)

#Confussion matrix
nb_conf_matrix = confusion_matrix(Y_test, X_test_prediction)
print("Confussion matrix")
print(nb_conf_matrix)
# Out:
# Accuracy on Training data:  84.11458333333334
# Accuracy on Test data:  82.87937743190662
# Confussion matrix
# [[106  32]
#  [ 12 107]]

# %%
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### Random Forest

# %%
m3="Random Forest"
rf = RandomForestClassifier(n_estimators=100, criterion="entropy",max_depth=7, min_samples_leaf=2, max_features="sqrt",random_state=2)  
# training the model with training data
rf.fit(X_train,Y_train)
# Accuracy on training data
X_train_prediction = rf.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)

# Accuracy on test data
X_test_prediction = rf.predict(X_test)
test_data_accuracy_rf = accuracy_score(X_test_prediction, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_rf*100)

#Confussion matrix
rf_conf_matrix = confusion_matrix(Y_test, X_test_prediction)
print("Confussion matrix")
print(rf_conf_matrix)
# Out:
# Accuracy on Training data:  98.828125
# Accuracy on Test data:  94.94163424124513
# Confussion matrix
# [[129   9]
#  [  4 115]]

# %%
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### Extreme Gradient Boost

# %%
m4="Extreme Gradient Boost"
Egb = GradientBoostingClassifier(n_estimators=100, subsample= 0.2, min_samples_leaf=2,max_depth=5,random_state=2,max_features="sqrt")
# training the model with training data
Egb.fit(X_train,Y_train)
# Accuracy on training data
X_train_prediction = Egb.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)
# Accuracy on test data
X_test_prediction = Egb.predict(X_test)
test_data_accuracy_egb = accuracy_score(X_test_prediction, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_egb*100)

#Confussion matrix
Egb_conf_matrix = confusion_matrix(Y_test, X_test_prediction)
print("Confussion matrix")
print(Egb_conf_matrix)
# Out:
# Accuracy on Training data:  100.0
# Accuracy on Test data:  97.27626459143968
# Confussion matrix
# [[134   4]
#  [  3 116]]

# %%
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### K-Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
m5="K-Neighbour"
knn = KNeighborsClassifier(n_neighbors=20, algorithm="auto" )
# train on the training set
knn.fit(X_train, Y_train)
# Accuracy on training data
X_train_predict= knn.predict(X_train)
training_data_accuracy=accuracy_score(X_train_predict, Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)
# Accuracy on test data
X_test_predict= knn.predict(X_test)
test_data_accuracy_knn=accuracy_score(X_test_predict, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_knn*100)
#Confussion matrix
knn_confusion_matrix=  confusion_matrix(Y_test,X_test_predict)
print("Confusion Matrix")
print(knn_confusion_matrix)
# Out:
# Accuracy on Training data:  85.80729166666666
# Accuracy on Test data:  85.99221789883269
# Confusion Matrix
# [[115  23]
#  [ 13 106]]

# %%
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### XGB

# %%
from xgboost import  XGBClassifier
m6="XGB"
xgb = XGBClassifier()
xgb.fit(X_train, Y_train)
# Accuracy on training data
X_train_predict= xgb.predict(X_train)
training_data_accuracy=accuracy_score(X_train_predict, Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)
# Accuracy on test data
X_test_predict= xgb.predict(X_test)
test_data_accuracy_xgb=accuracy_score(X_test_predict, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_xgb*100)
#Confussion matrix
knn_confusion_matrix=  confusion_matrix(Y_test,X_test_predict)
print("Confusion Matrix")
print(knn_confusion_matrix)
# Out:
# Accuracy on Training data:  100.0
# Accuracy on Test data:  97.27626459143968
# Confusion Matrix
# [[134   4]
#  [  3 116]]

# %%
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### svc

# %%
from sklearn.svm import SVC
m7="svc"
svc = SVC(C=5,kernel="rbf")
svc.fit(X_train, Y_train)
# Accuracy on training data
X_train_predict= svc.predict(X_train)
training_data_accuracy=accuracy_score(X_train_predict, Y_train)
print(f"Accuracy on Training data: ",training_data_accuracy*100)
# Accuracy on test data
X_test_predict= svc.predict(X_test)
test_data_accuracy_svc=accuracy_score(X_test_predict, Y_test)
print(f"Accuracy on Test data: ",test_data_accuracy_svc*100)
#Confussion matrix
knn_confusion_matrix =  confusion_matrix(Y_test,X_test_predict)
print("Confusion Matrix")
print(knn_confusion_matrix)
# Out:
# Accuracy on Training data:  98.95833333333334
# Accuracy on Test data:  94.55252918287937
# Confusion Matrix
# [[127  11]
#  [  3 116]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score,log_loss, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score,classification_report
ConfusionMatrixDisplay.from_predictions( Y_test, X_test_prediction, normalize="true", values_format=".0%")

# %% [markdown]
# ### comparision of all models

# %%
results = {"Models": [m1, m2, m3 ,m4, m5, m6,m7],
           "Accuracy": [test_data_accuracy_lr, test_data_accuracy_nb, test_data_accuracy_rf,test_data_accuracy_egb, test_data_accuracy_knn, test_data_accuracy_xgb, test_data_accuracy_svc]}
    
for (key, value) in results.items():
    if key=="Accuracy":
        results[key]=  [item*100 for item in results[key]]

    
result_df=pd.DataFrame(results)

# %%
result_df
# Out:
#                    Models   Accuracy
# 0     Logistic Regression  82.879377
# 1             Naive Bayes  82.879377
# 2           Random Forest  94.941634
# 3  Extreme Gradient Boost  97.276265
# 4             K-Neighbour  85.992218
# 5                     XGB  97.276265
# 6                     svc  94.552529

# %%
# %matplotlib inline
colors = ['red','green','blue','gold','silver','yellow','orange',]
plt.figure(figsize=(12,5))
plt.title("barplot Represent Accuracy of different models")
plt.xlabel("Accuracy %")
plt.ylabel("Algorithms")
plt.bar(result_df['Models'],result_df['Accuracy'],color = colors)
plt.show()

# %% [markdown]
# # xgboost classifier model give us the 97% accurate result

# %% [markdown]
# # now apply the hyperperameter tuning of xgboost model

# %%
import optuna
Random_s=np.random.seed(30)
def objective(trial):
    params = {
        'booster': trial.suggest_categorical('booster', ['gbtree']),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 300, 700),
        'min_child_weight': trial.suggest_int('min_child_weight', 0.01, 1),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.1, 1),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.1, 1),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.01, 1),
        'eval_metric':trial.suggest_categorical('eval_metric', ['mlogloss']),
    }

    optuna_xgbmodel=XGBClassifier(**params, random_state=Random_s)
    optuna_xgbmodel.fit(X_train,Y_train)
    Y_pred_prob=optuna_xgbmodel.predict_proba(X_test)
    logloss=log_loss(Y_test,Y_pred_prob)
    return logloss
study=optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50,show_progress_bar=True)
# Out:
# [I 2024-01-09 19:49:02,574] A new study created in memory with name: no-name-f8aec944-ec31-4945-89fd-7b810a433d66
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2024-01-09 19:49:03,011] Trial 0 finished with value: 0.24240135415218675 and parameters: {'booster': 'gbtree', 'max_depth': 3, 'learning_rate': 0.02876611484033656, 'n_estimators': 616, 'min_child_weight': 1, 'subsample': 0.15824595774054245, 'colsample_bylevel': 0.7998263117424057, 'colsample_bytree': 0.3918654703833452, 'colsample_bynode': 0.8039834052114103, 'reg_alpha': 0.21916749500913973, 'reg_lambda': 0.7377755849328055, 'eval_metric': 'mlogloss'}. Best is trial 0 with value: 0.24240135415218675.
 'eval_metric': 'mlogloss'}. Best is trial 1 with value: 0.08115596912806047.
# [I 2024-01-09 19:49:06,780] Trial 9 finished with value: 0.19173157567358767 and parameters: {'booster': 'gbtree', 'max_depth': 8, 'learning_rate': 0.01595108488912301, 'n_estimators': 608, 'min_child_weight': 1, 'subsample': 0.8711611462148778, 'colsample_bylevel': 0.49673692433296945, 'colsample_bytree': 0.9194103528936514, 'colsample_bynode': 0.34199050588478375, 'reg_alpha': 0.7146700392709098, 'reg_lambda': 0.6587346158692325, 'eval_metric': 'mlogloss'}. Best is trial 1 with value: 0.08115596912806047.
# [I 2024-01-09 19:49:07,338] Trial 10 finished with value: 0.07646064270655595 and parameters: {'booster': 'gbtree', 'max_depth': 12, 'learning_rate': 0.056736069660452526, 'n_estimators': 328, 'min_child_weight': 0, 'subsample': 0.7395286422116093, 'colsample_bylevel': 0.3496265977592531, 'colsample_bytree': 0.721525735676754, 'colsample_bynode': 0.9892218475715946, 'reg_alpha': 0.0113873984125204, 'reg_lambda': 0.011015720781230698, 'eval_metric': 'mlogloss'}. Best is trial 10 with value: 0.07646064270655595.
# [I 2024-01-09 19:49:07,902] Trial 11 finished with value: 0.07984531666930922 and parameters: {'booster': 'gbtree', 'max_depth': 12, 'learning_rate': 0.05563901847930588, 'n_estimators': 306, 'min_child_weight': 0, 'subsample': 0.7238537544131372, 'colsample_bylevel': 0.9955411699975241, 'colsample_bytree': 0.7155538885589606, 'colsample_bynode': 0.9741144620865432, 'reg_alpha': 0.012615146733476357, 'reg_lambda': 0.03206280033258412, 'eval_metric': 'mlogloss'}. Best is trial 10 with value: 0.07646064270655595.
# [I 2024-01-09 19:49:08,471] Trial 12 finished with value: 0.08804068372873274 and parameters: {'booster': 'gbtree', 'max_depth': 12, 'learning_rate': 0.06205160020055786, 'n_estimators': 301, 'min_child_weight': 0, 'subsample': 0.9979166635218023, 'colsample_bylevel': 0.9735084796178433, 'colsample_bytree': 0.7701402442486687, 'colsample_bynode': 0.9959242601579867, 'reg_alpha': 0.01468421513677293, 'reg_lambda': 0.02769878199316658, 'eval_metric': 'mlogloss'}. Best is trial 10 with value: 0.07646064270655595.
# [I 2024-01-09 19:49:08,980] Trial 13 finished with value: 0.0640339087729398 and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.055545901292869786, 'n_estimators': 375, 'min_child_weight': 0, 'subsample': 0.7398131824533075, 'colsample_bylevel': 0.9747126827490368, 'colsample_bytree': 0.7829969702891322, 'colsample_bynode': 0.9911135451268469, 'reg_alpha': 0.3425388633801807, 'reg_lambda': 0.03267636657532572, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:09,419] Trial 14 finished with value: 0.07834884639429229 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.07361907690296851, 'n_estimators': 395, 'min_child_weight': 0, 'subsample': 0.7910425797522651, 'colsample_bylevel': 0.3593641678193176, 'colsample_bytree': 0.8182557505345323, 'colsample_bynode': 0.8546381892458028, 'reg_alpha': 0.32513189101284307, 'reg_lambda': 0.20229895183008545, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:10,021] Trial 15 finished with value: 0.0678037780617231 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0
and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.06763462127550299, 'n_estimators': 353, 'min_child_weight': 0, 'subsample': 0.7854203588887027, 'colsample_bylevel': 0.8031626450904039, 'colsample_bytree': 0.6453853283163202, 'colsample_bynode': 0.9422349792395956, 'reg_alpha': 0.26220453991373716, 'reg_lambda': 0.07774095985834362, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:17,185] Trial 32 finished with value: 0.09205400806458837 and parameters: {'booster': 'gbtree', 'max_depth': 12, 'learning_rate': 0.0581775240737105, 'n_estimators': 340, 'min_child_weight': 0, 'subsample': 0.6983720909060906, 'colsample_bylevel': 0.40239582281761654, 'colsample_bytree': 0.5652899395957487, 'colsample_bynode': 0.8133164868549204, 'reg_alpha': 0.18729610919589168, 'reg_lambda': 0.08323616260361724, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:17,685] Trial 33 finished with value: 0.08159910916146072 and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.03517796814394976, 'n_estimators': 483, 'min_child_weight': 0, 'subsample': 0.6017339998545786, 'colsample_bylevel': 0.5166932825633137, 'colsample_bytree': 0.6891239242253276, 'colsample_bynode': 0.9282683585824537, 'reg_alpha': 0.33469740906726264, 'reg_lambda': 0.14585597212598206, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:18,126] Trial 34 finished with value: 0.06691457593551987 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.07626612980505625, 'n_estimators': 650, 'min_child_weight': 0, 'subsample': 0.8529075788502212, 'colsample_bylevel': 0.26814902418753667, 'colsample_bytree': 0.7902703528992588, 'colsample_bynode': 0.8390396784449714, 'reg_alpha': 0.12911022087422838, 'reg_lambda': 0.06450936038346841, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:18,584] Trial 35 finished with value: 0.08530900200648214 and parameters: {'booster': 'gbtree', 'max_depth': 6, 'learning_rate': 0.07683429974535794, 'n_estimators': 662, 'min_child_weight': 0, 'subsample': 0.8293265705779448, 'colsample_bylevel': 0.27672784925335214, 'colsample_bytree': 0.7910237607301018, 'colsample_bynode': 0.4751838737367595, 'reg_alpha': 0.12493684379464562, 'reg_lambda': 0.20625328098492812, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:19,025] Trial 36 finished with value: 0.07634193582645657 and parameters: {'booster': 'gbtree', 'max_depth': 9, 'learning_rate': 0.09794130154786557, 'n_estimators': 579, 'min_child_weight': 0, 'subsample': 0.881762903367294, 'colsample_bylevel': 0.6014963376156311, 'colsample_bytree': 0.8737271478646045, 'colsample_bynode': 0.6626950630516337, 'reg_alpha': 0.10203114493239263, 'reg_lambda': 0.05230071590951618, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:19,470] Trial 37 finished with value: 0.06506084029614743 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.07279884034304507, 'n_estimators': 660, 'min_child_weight': 1, 'subsample': 0.9926273680928236, 'colsample_bylevel': 0.7244983393178716, 'colsample_bytree': 0.9216691291910052, 'colsample_bynode': 0.8496491685246851, 'reg_alpha': 0.20400653810380545, 'reg_lambda': 0.130859867395541, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:19,771] Trial 38 finished with value: 0.10568498112930995 and parameters: {'booster': 'gbtree', 'max_depth': 4, 'learning_rate': 0.07202773768386952, 'n_estimators': 637, 'min_child_weight': 1, 'subsample': 0.9814704009529136, 'colsample_bylevel': 0.7236998022335828, 'colsample_bytree': 0.28104432327379486, 'colsample_bynode': 0.6985609638976018, 'reg_alpha': 0.20456192895689243, 'reg_lambda': 0.2878597022417725, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:20,171] Trial 39 finished with value: 0.1395642323455924 and parameters: {'booster': 'gbtree', 'max_depth': 9, 'learning_rate': 0.08634603292228285, 'n_estimators': 644, 'min_child_weight': 1, 'subsample': 0.5174722427217635, 'colsample_bylevel': 0.10834337958032042, 'colsample_bytree': 0.13956537177221606, 'colsample_bynode': 0.8424902743997817, 'reg_alpha': 0.06893233150285039, 'reg_lambda': 0.539155274665873, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:20,852] Trial 40 finished with value: 0.09427280085618213 and parameters: {'booster': 'gbtree', 'max_depth': 8, 'learning_rate': 0.010257911513837217, 'n_estimators': 674, 'min_child_weight': 1, 'subsample': 0.8901463422561517, 'colsample_bylevel': 0.6534297484551064, 'colsample_bytree': 0.8264915950744385, 'colsample_bynode': 0.7704811252361707, 'reg_alpha': 0.19938876613674372, 'reg_lambda': 0.01136067977729116, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:21,317] Trial 41 finished with value: 0.08950412314941857 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.07896198382138782, 'n_estimators': 681, 'min_child_weight': 1, 'subsample': 0.9493482869552332, 'colsample_bylevel': 0.770293924941389, 'colsample_bytree': 0.9258309192788359, 'colsample_bynode': 0.6179115070062655, 'reg_alpha': 0.1582954682156006, 'reg_lambda': 0.1435791657679633, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:21,755] Trial 42 finished with value: 0.09073472462910427 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.06562908623694792, 'n_estimators': 646, 'min_child_weight': 1, 'subsample': 0.9111109842949773, 'colsample_bylevel': 0.18794329439241408, 'colsample_bytree': 0.9033668018295726, 'colsample_bynode': 0.8992138861121867, 'reg_alpha': 0.4141917411659689, 'reg_lambda': 0.6233637387464203, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:22,202] Trial 43 finished with value: 0.08292970607131665 and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.07266903475411343, 'n_estimators': 589, 'min_child_weight': 1, 'subsample': 0.8446364988522124, 'colsample_bylevel': 0.8706760907515063, 'colsample_bytree': 0.9948453844499386, 'colsample_bynode': 0.529329259242886, 'reg_alpha': 0.2707636418882919, 'reg_lambda': 0.11523879993567113, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:22,972] Trial 44 finished with value: 0.06861840634027365 and parameters: {'booster': 'gbtree', 'max_depth': 9, 'learning_rate': 0.04453631700066103, 'n_estimators': 544, 'min_child_weight': 0, 'subsample': 0.9976390388185374, 'colsample_bylevel': 0.9516662911014997, 'colsample_bytree': 0.9360739381747104, 'colsample_bynode': 0.7801388179482963, 'reg_alpha': 0.0594208073879811, 'reg_lambda': 0.8261678523350136, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:23,417] Trial 45 finished with value: 0.08332559242975252 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.09217353840398554, 'n_estimators': 658, 'min_child_weight': 0, 'subsample': 0.7831644351182183, 'colsample_bylevel': 0.5479998431050054, 'colsample_bytree': 0.7620406694752336, 'colsample_bynode': 0.9356990018474873, 'reg_alpha': 0.38815961771079915, 'reg_lambda': 0.24986140204271992, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:23,919] Trial 46 finished with value: 0.0884588963543206 and parameters: {'booster': 'gbtree', 'max_depth': 8, 'learning_rate': 0.08301908019110552, 'n_estimators': 621, 'min_child_weight': 1, 'subsample': 0.8317860705242568, 'colsample_bylevel': 0.7350446216250238, 'colsample_bytree': 0.8522049232799948, 'colsample_bynode': 0.7291139534900278, 'reg_alpha': 0.4875321633542323, 'reg_lambda': 0.18181412310568046, 'eval_metric': 'mlogloss'}. Best is trial 13 with value: 0.0640339087729398.
# [I 2024-01-09 19:49:24,427] Trial 47 finished with value: 0.060288654172748764 and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.05413763654342785, 'n_estimators': 569, 'min_child_weight': 0, 'subsample': 0.953786584120994, 'colsample_bylevel': 0.6811195409977988, 'colsample_bytree': 0.5011009216565342, 'colsample_bynode': 0.8664555837805419, 'reg_alpha': 0.3165966244077707, 'reg_lambda': 0.06234449817408756, 'eval_metric': 'mlogloss'}. Best is trial 47 with value: 0.060288654172748764.
# [I 2024-01-09 19:49:24,851] Trial 48 finished with value: 0.06342944632573874 and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.0699207537654842, 'n_estimators': 568, 'min_child_weight': 0, 'subsample': 0.6167159905619921, 'colsample_bylevel': 0.6263292847632799, 'colsample_bytree': 0.4732783337583829, 'colsample_bynode': 0.8583487608748183, 'reg_alpha': 0.3236907168958146, 'reg_lambda': 0.0578540301517398, 'eval_metric': 'mlogloss'}. Best is trial 47 with value: 0.060288654172748764.
# [I 2024-01-09 19:49:25,229] Trial 49 finished with value: 0.10323801610535986 and parameters: {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.06883118298072155, 'n_estimators': 562, 'min_child_weight': 0, 'subsample': 0.5485444983561857, 'colsample_bylevel': 0.6269679690538095, 'colsample_bytree': 0.45917882822705053, 'colsample_bynode': 0.4112862942732929, 'reg_alpha': 0.3207289350667001, 'reg_lambda': 0.060787360627895026, 'eval_metric': 'mlogloss'}. Best is trial 47 with value: 0.060288654172748764.

# %%
print("best hypertuning", study.best_params)
print("log loss" , study.best_value)
# Out:
# best hypertuning {'booster': 'gbtree', 'max_depth': 11, 'learning_rate': 0.05413763654342785, 'n_estimators': 569, 'min_child_weight': 0, 'subsample': 0.953786584120994, 'colsample_bylevel': 0.6811195409977988, 'colsample_bytree': 0.5011009216565342, 'colsample_bynode': 0.8664555837805419, 'reg_alpha': 0.3165966244077707, 'reg_lambda': 0.06234449817408756, 'eval_metric': 'mlogloss'}
# log loss 0.060288654172748764

# %%
parameters= study.best_params
xgb_model_2=XGBClassifier(**parameters,random_state=Random_s)
xgb_model_2.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=0.6811195409977988,
#               colsample_bynode=0.8664555837805419,
#               colsample_bytree=0.5011009216565342, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05413763654342785,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=0, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=569, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
peredtic = xgb_model_2.predict(X_test)
print("accuracy score =",accuracy_score(Y_test,peredtic))
print('precision score =', precision_score(Y_test,peredtic,average='weighted'))
print("Recall =",recall_score(Y_test,peredtic,average='weighted'))
# Out:
# accuracy score = 0.9727626459143969
# precision score = 0.9728071421132855
# Recall = 0.9727626459143969

# %%
ConfusionMatrixDisplay.from_predictions( Y_test, peredtic, normalize="true", values_format=".0%")
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## I have the dataset of some heart patient which have 13 feature  and 1 target column. Target column of my dataset have two category either the person has diesese or don't have the disease. My data set don't have any null values and outliers. None of the feature depends on other. I use the train test split to split the data into to part for training and testing the model.I use 7 model ( logestic regression,navie bayes,random forest,Extreme gradient boost,K-Neighbour,XGBoost,SVC) and i calculate the accuracy of each model.I found the on the given data set XGBoost model give us the best result with 97% accuracy. to improve the performance of model i use hyperperameter tuning and it slightly improve the accuracy of the model
